# %% [markdown]
# # Customer Churn Prediction (Logistic Regression) — 04_model_selection_metrics.ipynb
#
# **Author:** YOUR NAME
# **Date:** 2025-09-13
#
# **Objective:** Briefly explain what this notebook accomplishes and the expected output.

# %%
# Standard imports
import os, sys, json
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Ensure src/ is on path
ROOT = Path(__file__).resolve().parents[1]
SRC = ROOT / "src"
if SRC.exists():
    sys.path.append(str(SRC))
print("Working dir:", os.getcwd())

# %% [markdown]
# ## Business Context
# - Summarize the specific question this notebook answers.

# %% [markdown]
# ## Data Loading & Preparation

# %% [markdown]
# ## Analysis / Modeling

# %% [markdown]
# ## Results & Visuals

# %% [markdown]
# ## Takeaways / Next Steps
